# %% [markdown]
# ### Kullanılacak kütüphaneler
# * pandas
# * numpy
# * matplotlib
# * seaborn

# %% [markdown]
# #### from ve import

# %%
import pandas as pd

# %% [markdown]
# ![](https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png)

# %%
meyve = pd.Series(["Elma","Armut","Portakal"])
meyve
# Out:
# 0        Elma
# 1       Armut
# 2    Portakal
# dtype: object

# %%
fiyat = pd.Series([10,20,12])
fiyat
# Out:
# 0    10
# 1    20
# 2    12
# dtype: int64

# %%
import numpy as np

# %%
df = pd.DataFrame({"Meyve":meyve,"Fiyat":fiyat,"Miktar":[200,300,100]})
df
# Out:
#       Meyve  Fiyat  Miktar
# 0      Elma     10     200
# 1     Armut     20     300
# 2  Portakal     12     100

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Meyve', 'Fiyat', 'Miktar'], dtype='object')

# %%
# df.columns = ["Fruit","Cost"]

# %%
df
# Out:
#       Meyve  Fiyat  Miktar
# 0      Elma     10     200
# 1     Armut     20     300
# 2  Portakal     12     100

# %%
import pandas as pd

# %%
df.to_csv("Data/ornek.csv",index=False)

# %%
df = pd.read_csv("Data/50_StartupswithNaN.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70             NaN        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54         NaN  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77              NaN     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# * head

# %%
df.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70             NaN        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54         NaN  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77              NaN     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %% [markdown]
# * tail

# %%
df.tail(10)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 40   28754.33       118546.05        172795.67  California  78239.91
# 41   27892.92        84710.77        164470.71     Florida  77798.83
# 42   23640.93        96189.63        148001.11  California  71498.49
# 43   15505.73       127382.30         35534.17    New York  69758.98
# 44   22177.74       154806.14         28334.72  California  65200.33
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %% [markdown]
# * dtypes

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %% [markdown]
# * info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   48 non-null     float64
#  2   Marketing Spend  48 non-null     float64
#  3   State            47 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df = pd.read_csv("Data/heart.csv")

# %% [markdown]
# * describe

# %%
df.describe()
# Out:
#           AGE_50       MD_50      SBP_50      DBP_50       HT_50       WT_50  \
# count  200.00000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    46.06500    2.360000  124.700000   83.380000   68.160000  168.075000
# std     10.81274    1.017633   18.114654   11.000484    2.768161   26.639589
# min     20.00000    1.000000   88.000000   38.000000   61.000000  109.000000
# 25%     38.00000    1.000000  110.000000   78.000000   66.000000  147.000000
# 50%     47.00000    2.000000  120.000000   80.000000   68.000000  165.000000
# 75%     54.00000    3.000000  130.000000   90.000000   70.000000  189.000000
# max     69.00000    4.000000  210.000000  140.000000   75.000000  245.000000
#
#           CHOL_50         SES   CL_STATUS       MD_62      SBP_62      DBP_62  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   258.105000    2.915000    7.650000    2.315000  141.480000   84.820000
# ...

# %%
df.count()
# Out:
# AGE_50       200
# MD_50        200
# SBP_50       200
# DBP_50       200
# HT_50        200
# WT_50        200
# CHOL_50      200
# SES          200
# CL_STATUS    200
# MD_62        200
# SBP_62       200
# DBP_62       200
# CHOL_62      200
# WT_62        200
# IHD_DX       200
# DEATH        200
# dtype: int64

# %%
df.mean()
# Out:
# AGE_50        46.065
# MD_50          2.360
# SBP_50       124.700
# DBP_50        83.380
# HT_50         68.160
# WT_50        168.075
# CHOL_50      258.105
# SES            2.915
# CL_STATUS      7.650
# MD_62          2.315
# SBP_62       141.480
# DBP_62        84.820
# CHOL_62      254.070
# WT_62        167.375
# IHD_DX         1.410
# DEATH          0.320
# dtype: float64

# %% [markdown]
# * quantile

# %%
df.quantile(0.25)
# Out:
# AGE_50        38.00
# MD_50          1.00
# SBP_50       110.00
# DBP_50        78.00
# HT_50         66.00
# WT_50        147.00
# CHOL_50      220.00
# SES            2.00
# CL_STATUS      8.00
# MD_62          1.00
# SBP_62       125.00
# DBP_62        76.00
# CHOL_62      222.75
# WT_62        148.75
# IHD_DX         0.00
# DEATH          0.00
# Name: 0.25, dtype: float64

# %% [markdown]
# * Sütunlar ile verilere erişim

# %%
df["AGE_50"].head()
# Out:
# 0    42
# 1    53
# 2    53
# 3    48
# 4    53
# Name: AGE_50, dtype: int64

# %%
df.AGE_50.head()
# Out:
# 0    42
# 1    53
# 2    53
# 3    48
# 4    53
# Name: AGE_50, dtype: int64

# %% [markdown]
# * loc
# * iloc

# %%
hayvanlar = pd.Series(["kedi","kopek","kuş","yılan","kurbağa","penguen"],
index=[0,3,9,8,67,3])
hayvanlar
# Out:
# 0        kedi
# 3       kopek
# 9         kuş
# 8       yılan
# 67    kurbağa
# 3     penguen
# dtype: object

# %%
hayvanlar.loc[3]
# Out:
# 3      kopek
# 3    penguen
# dtype: object

# %%
hayvanlar.iloc[3]
# Out:
# 'yılan'

# %%
hayvanlar[3]
# Out:
# 3      kopek
# 3    penguen
# dtype: object

# %%
df.iloc[:,:]
# Out:
#      AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 0        42      1     110      65     64    147      291    2          8
# 1        53      1     130      72     69    167      278    1          6
# 2        53      2     120      90     70    222      342    4          8
# 3        48      4     120      80     72    229      239    4          8
# 4        53      3     118      74     66    134      243    3          8
# ..      ...    ...     ...     ...    ...    ...      ...  ...        ...
# 195      50      1     115      80     66    148      300    2          8
# 196      23      1     110      70     69    137      120    3          8
# 197      20      3     130      80     66    150      210    5          0
# 198      46      3     140      84     66    138      130    4          6
# 199      36      1     100      70     70    157      260    3          8
#
#      MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# ...

# %%
df.iloc[0:20,:]
# Out:
#     AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 0       42      1     110      65     64    147      291    2          8
# 1       53      1     130      72     69    167      278    1          6
# 2       53      2     120      90     70    222      342    4          8
# 3       48      4     120      80     72    229      239    4          8
# 4       53      3     118      74     66    134      243    3          8
# 5       58      2     122      72     69    135      210    3          8
# 6       48      4     130      90     67    165      219    3          8
# 7       60      1     124      80     74    235      203    3          8
# 8       59      4     160     100     72    206      269    5          8
# 9       40      3     120      80     69    148      185    3          8
# 10      56      3     115      80     64    147      260    3          8
# 11      58      3     140      90     63    121      312    5          8
# ...

# %%
df.iloc[0:20,0:2].head()
# Out:
#    AGE_50  MD_50
# 0      42      1
# 1      53      1
# 2      53      2
# 3      48      4
# 4      53      3

# %% [markdown]
# * shape

# %%
df.shape
# Out:
# (200, 16)

# %% [markdown]
# * sorting

# %%
df.sort_values("AGE_50",ascending=False)
# Out:
#      AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 105      69      1     160      90     67    185      314    4          8
# 72       68      3     120      80     63    109      215    1          8
# 95       65      4     125      85     67    164      228    5          8
# 88       65      1     170     105     67    183      214    5          3
# 33       64      1     144      95     66    191      244    1          8
# ..      ...    ...     ...     ...    ...    ...      ...  ...        ...
# 138      25      4     120      84     72    180      220    3          8
# 32       24      3     104      75     70    157      185    5          8
# 196      23      1     110      70     69    137      120    3          8
# 177      22      4     120      90     69    192      240    5          8
# 197      20      3     130      80     66    150      210    5          0
#
#      MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# ...

# %%
df.sort_values(["AGE_50","DBP_50"],ascending=[True,False])
# Out:
#      AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 197      20      3     130      80     66    150      210    5          0
# 177      22      4     120      90     69    192      240    5          8
# 196      23      1     110      70     69    137      120    3          8
# 32       24      3     104      75     70    157      185    5          8
# 138      25      4     120      84     72    180      220    3          8
# ..      ...    ...     ...     ...    ...    ...      ...  ...        ...
# 170      64      4     104      74     63    146      300    3          8
# 88       65      1     170     105     67    183      214    5          3
# 95       65      4     125      85     67    164      228    5          8
# 72       68      3     120      80     63    109      215    1          8
# 105      69      1     160      90     67    185      314    4          8
#
#      MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# ...

# %%
dfSart = df[(df["AGE_50"]>20)&(df["SBP_50"] == 120) ]

# %%
dfSart.reset_index(drop=True,inplace=True)

# %%
dfSart
# Out:
#      AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 2        53      2     120      90     70    222      342    4          8
# 3        48      4     120      80     72    229      239    4          8
# 9        40      3     120      80     69    148      185    3          8
# 19       28      1     120      86     70    189      328    3          8
# 25       51      4     120      80     70    139      261    3          8
# 26       49      1     120      80     68    194      263    3          8
# 29       35      2     120      80     72    191      321    3          8
# 44       51      3     120      90     66    163      226    3          8
# 45       44      2     120      90     72    211      188    3          8
# 48       30      2     120      84     68    170      258    3          8
# 72       68      3     120      80     63    109      215    1          8
# 76       62      1     120      80     68    174      535    2          8
# ...

# %% [markdown]
# * isin

# %%
sart = df["AGE_50"].isin([30,40])
df[sart]
# Out:
#      AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 9        40      3     120      80     69    148      185    3          8
# 35       30      3     110      80     71    198      234    2          8
# 48       30      2     120      84     68    170      258    3          8
# 49       40      1     112      80     69    167      334    3          8
# 102      30      2     160      85     71    155      187    3          8
# 120      40      2     100      70     68    169      260    2          6
# 126      30      3     115      86     70    172      210    2          8
# 132      30      1     104      70     69    161      300    3          8
# 169      30      2     106      80     70    173      260    4          8
# 173      30      4     120      80     70    130      260    3          8
#
#      MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# 9        3     110      64      241    152       2      1
# ...

# %%
df["AGE_50_2"] = df["AGE_50"] ** 2

# %%
df[["AGE_50","AGE_50_2"]].head()
# Out:
#    AGE_50  AGE_50_2
# 0      42      1764
# 1      53      2809
# 2      53      2809
# 3      48      2304
# 4      53      2809

# %% [markdown]
# * agg

# %%
df["AGE_50"].agg([sum])
# Out:
# sum    9213
# Name: AGE_50, dtype: int64

# %%
def fonk(a):
    return a**2
y10 = lambda c:c.quantile(0.1)
y90 = lambda c:c.quantile(0.9)
df["AGE_50"].agg([y10,y90])
# Out:
# <lambda>    30.0
# <lambda>    60.0
# Name: AGE_50, dtype: float64

# %%
df["AGE_50"] = df["AGE_50"].apply(lambda x:x//2)
df.head()
# Out:
#    AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 0      21      1     110      65     64    147      291    2          8
# 1      26      1     130      72     69    167      278    1          6
# 2      26      2     120      90     70    222      342    4          8
# 3      24      4     120      80     72    229      239    4          8
# 4      26      3     118      74     66    134      243    3          8
#
#    MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH  AGE_50_2
# 0      4     120      78      271    146       2      1      1764
# 1      2     122      68      250    165       9      1      2809
# 2      1     132      90      304    223       2      1      2809
# 3      2     118      68      209    227       3      1      2304
# 4      5     118      56      261    138       2      1      2809

# %% [markdown]
# * value counts

# %%
df["DEATH"].value_counts()
# Out:
# DEATH
# 0    136
# 1     64
# Name: count, dtype: int64

# %%
df.drop("AGE_50",axis=1,inplace=True)
# Out:
#      MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  MD_62  \
# 0        1     110      65     64    147      291    2          8      4
# 1        1     130      72     69    167      278    1          6      2
# 2        2     120      90     70    222      342    4          8      1
# 3        4     120      80     72    229      239    4          8      2
# 4        3     118      74     66    134      243    3          8      5
# ..     ...     ...     ...    ...    ...      ...  ...        ...    ...
# 195      1     115      80     66    148      300    2          8      1
# 196      1     110      70     69    137      120    3          8      2
# 197      3     130      80     66    150      210    5          0      1
# 198      3     140      84     66    138      130    4          6      2
# 199      1     100      70     70    157      260    3          8      3
#
#      SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH  AGE_50_2
# ...

# %%
df["AGE_50_2"].values
# Out:
# array([1764, 2809, 2809, 2304, 2809, 3364, 2304, 3600, 3481, 1600, 3136,
#        3364, 4096, 3249, 1024, 3481, 2304, 2209, 2209,  784, 1369, 2916,
#        1444, 2704, 2116, 2601, 2401, 2116,  676, 1225, 2025, 3249,  576,
#        4096, 1156,  900, 2704, 3136, 1936, 2025,  841, 1764, 2116, 2025,
#        2601, 1936, 1024, 1156,  900, 1600, 1156, 1849, 1521, 2025, 1681,
#        3249, 2809, 3025, 3249, 1444, 2025, 1089, 3721, 1296, 1369, 2601,
#        2116, 2601, 3600, 3249, 3969, 3969, 4624, 3249, 4096, 3969, 3844,
#        3025, 2500, 1521, 2500, 1764, 2809, 3136, 3844, 3721, 3249, 1849,
#        4225, 2401, 2209, 3481, 2809, 1849, 2704, 4225, 2500, 1089, 2401,
#        3844, 2025, 2809,  900,  625,  676, 4761, 3600, 2025, 3025, 3969,
#        2704, 2809, 3025, 2304, 2500, 1936, 2401, 3721, 1764, 2209, 1600,
#        1089,  841, 1849, 2601, 3249,  900, 1936, 1936, 1444, 1225, 1156,
#         900, 2601, 2601, 3249, 2116, 2500,  625, 3025, 2209, 2401, 2209,
# ...
